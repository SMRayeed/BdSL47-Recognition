# %% [markdown]
# <a href="https://www.kaggle.com/code/rayeed045/bdsl37-finalized-code?scriptVersionId=120221154" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from numpy import mean
from sklearn import metrics
import seaborn as ss
import os

# %% [markdown]
# ### ***Load Dataset***

# %%
user01_sign00 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_00.csv")
user01_sign01 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_01.csv")
user01_sign02 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_02.csv")
user01_sign03 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_03.csv")
user01_sign04 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_04.csv")
user01_sign05 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_05.csv")
user01_sign06 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_06.csv")
user01_sign07 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_07.csv")
user01_sign08 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_08.csv")
user01_sign09 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_09.csv")

user01_sign10 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_10.csv")
user01_sign11 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_11.csv")
user01_sign12 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_12.csv")
user01_sign13 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_13.csv")
user01_sign14 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_14.csv")
user01_sign15 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_15.csv")
user01_sign16 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_16.csv")
user01_sign17 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_17.csv")
user01_sign18 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_18.csv")
user01_sign19 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_19.csv")

user01_sign20 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_20.csv")
user01_sign21 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_21.csv")
user01_sign22 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_22.csv")
user01_sign23 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_23.csv")
user01_sign24 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_24.csv")
user01_sign25 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_25.csv")
user01_sign26 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_26.csv")
user01_sign27 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_27.csv")
user01_sign28 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_28.csv")
user01_sign29 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_29.csv")

user01_sign30 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_30.csv")
user01_sign31 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_31.csv")
user01_sign32 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_32.csv")
user01_sign33 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_33.csv")
user01_sign34 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_34.csv")
user01_sign35 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_35.csv")
user01_sign36 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 01 - Female, 24/Output Images - Sign_36.csv")

user02_sign00 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_00.csv")
user02_sign01 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_01.csv")
user02_sign02 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_02.csv")
user02_sign03 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_03.csv")
user02_sign04 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_04.csv")
user02_sign05 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_05.csv")
user02_sign06 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_06.csv")
user02_sign07 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_07.csv")
user02_sign08 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_08.csv")
user02_sign09 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_09.csv")

user02_sign10 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_10.csv")
user02_sign11 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_11.csv")
user02_sign12 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_12.csv")
user02_sign13 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_13.csv")
user02_sign14 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_14.csv")
user02_sign15 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_15.csv")
user02_sign16 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_16.csv")
user02_sign17 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_17.csv")
user02_sign18 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_18.csv")
user02_sign19 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_19.csv")

user02_sign20 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_20.csv")
user02_sign21 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_21.csv")
user02_sign22 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_22.csv")
user02_sign23 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_23.csv")
user02_sign24 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_24.csv")
user02_sign25 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_25.csv")
user02_sign26 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_26.csv")
user02_sign27 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_27.csv")
user02_sign28 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_28.csv")
user02_sign29 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_29.csv")

user02_sign30 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_30.csv")
user02_sign31 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_31.csv")
user02_sign32 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_32.csv")
user02_sign33 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_33.csv")
user02_sign34 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_34.csv")
user02_sign35 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_35.csv")
user02_sign36 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 02 - Male, 16/Output Images - Sign_36.csv")

user03_sign00 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_00.csv")
user03_sign01 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_01.csv")
user03_sign02 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_02.csv")
user03_sign03 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_03.csv")
user03_sign04 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_04.csv")
user03_sign05 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_05.csv")
user03_sign06 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_06.csv")
user03_sign07 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_07.csv")
user03_sign08 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_08.csv")
user03_sign09 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_09.csv")

user03_sign10 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_10.csv")
user03_sign11 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_11.csv")
user03_sign12 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_12.csv")
user03_sign13 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_13.csv")
user03_sign14 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_14.csv")
user03_sign15 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_15.csv")
user03_sign16 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_16.csv")
user03_sign17 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_17.csv")
user03_sign18 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_18.csv")
user03_sign19 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_19.csv")

user03_sign20 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_20.csv")
user03_sign21 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_21.csv")
user03_sign22 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_22.csv")
user03_sign23 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_23.csv")
user03_sign24 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_24.csv")
user03_sign25 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_25.csv")
user03_sign26 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_26.csv")
user03_sign27 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_27.csv")
user03_sign28 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_28.csv")
user03_sign29 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_29.csv")

user03_sign30 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_30.csv")
user03_sign31 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_31.csv")
user03_sign32 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_32.csv")
user03_sign33 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_33.csv")
user03_sign34 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_34.csv")
user03_sign35 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_35.csv")
user03_sign36 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 03 - Female, 21/Output Images - Sign_36.csv")

user04_sign00 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 00.csv")
user04_sign01 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 01.csv")
user04_sign02 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 02.csv")
user04_sign03 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 03.csv")
user04_sign04 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 04.csv")
user04_sign05 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 05.csv")
user04_sign06 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 06.csv")
user04_sign07 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 07.csv")
user04_sign08 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 08.csv")
user04_sign09 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 09.csv")

user04_sign10 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 10.csv")
user04_sign11 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 11.csv")
user04_sign12 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 12.csv")
user04_sign13 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 13.csv")
user04_sign14 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 14.csv")
user04_sign15 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 15.csv")
user04_sign16 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 16.csv")
user04_sign17 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 17.csv")
user04_sign18 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 18.csv")
user04_sign19 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 19.csv")

user04_sign20 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 20.csv")
user04_sign21 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 21.csv")
user04_sign22 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 22.csv")
user04_sign23 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 23.csv")
user04_sign24 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 24.csv")
user04_sign25 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 25.csv")
user04_sign26 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 26.csv")
user04_sign27 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 27.csv")
user04_sign28 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 28.csv")
user04_sign29 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 29.csv")

user04_sign30 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 30.csv")
user04_sign31 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 31.csv")
user04_sign32 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 32.csv")
user04_sign33 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 33.csv")
user04_sign34 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 34.csv")
user04_sign35 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 35.csv")
user04_sign36 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 04 - Female, 52/Output - BSL Image Frames - Sign - 36.csv")

user05_sign00 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 00.csv")
user05_sign01 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 01.csv")
user05_sign02 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 02.csv")
user05_sign03 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 03.csv")
user05_sign04 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 04.csv")
user05_sign05 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 05.csv")
user05_sign06 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 06.csv")
user05_sign07 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 07.csv")
user05_sign08 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 08.csv")
user05_sign09 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 09.csv")

user05_sign10 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 10.csv")
user05_sign11 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 11.csv")
user05_sign12 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 12.csv")
user05_sign13 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 13.csv")
user05_sign14 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 14.csv")
user05_sign15 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 15.csv")
user05_sign16 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 16.csv")
user05_sign17 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 17.csv")
user05_sign18 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 18.csv")
user05_sign19 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 19.csv")

user05_sign20 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 20.csv")
user05_sign21 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 21.csv")
user05_sign22 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 22.csv")
user05_sign23 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 23.csv")
user05_sign24 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 24.csv")
user05_sign25 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 25.csv")
user05_sign26 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 26.csv")
user05_sign27 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 27.csv")
user05_sign28 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 28.csv")
user05_sign29 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 29.csv")

user05_sign30 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 30.csv")
user05_sign31 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 31.csv")
user05_sign32 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 32.csv")
user05_sign33 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 33.csv")
user05_sign34 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 34.csv")
user05_sign35 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 35.csv")
user05_sign36 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 05 - Male, 24/Output - BSL Image Frames - Sign 36.csv")

user06_sign00 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 00.csv")
user06_sign01 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 01.csv")
user06_sign02 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 02.csv")
user06_sign03 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 03.csv")
user06_sign04 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 04.csv")
user06_sign05 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 05.csv")
user06_sign06 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 06.csv")
user06_sign07 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 07.csv")
user06_sign08 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 08.csv")
user06_sign09 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 09.csv")

user06_sign10 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 10.csv")
user06_sign11 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 11.csv")
user06_sign12 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 12.csv")
user06_sign13 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 13.csv")
user06_sign14 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 14.csv")
user06_sign15 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 15.csv")
user06_sign16 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 16.csv")
user06_sign17 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 17.csv")
user06_sign18 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 18.csv")
user06_sign19 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 19.csv")

user06_sign20 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 20.csv")
user06_sign21 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 21.csv")
user06_sign22 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 22.csv")
user06_sign23 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 23.csv")
user06_sign24 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 24.csv")
user06_sign25 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 25.csv")
user06_sign26 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 26.csv")
user06_sign27 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 27.csv")
user06_sign28 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 28.csv")
user06_sign29 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 29.csv")

user06_sign30 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 30.csv")
user06_sign31 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 31.csv")
user06_sign32 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 32.csv")
user06_sign33 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 33.csv")
user06_sign34 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 34.csv")
user06_sign35 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 35.csv")
user06_sign36 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 06 - Female, 21/Output - BSL Image Frames - Sign 36.csv")

user07_sign00 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 00.csv")
user07_sign01 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 01.csv")
user07_sign02 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 02.csv")
user07_sign03 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 03.csv")
user07_sign04 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 04.csv")
user07_sign05 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 05.csv")
user07_sign06 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 06.csv")
user07_sign07 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 07.csv")
user07_sign08 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 08.csv")
user07_sign09 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 09.csv")

user07_sign10 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 10.csv")
user07_sign11 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 11.csv")
user07_sign12 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 12.csv")
user07_sign13 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 13.csv")
user07_sign14 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 14.csv")
user07_sign15 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 15.csv")
user07_sign16 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 16.csv")
user07_sign17 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 17.csv")
user07_sign18 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 18.csv")
user07_sign19 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 19.csv")

user07_sign20 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 20.csv")
user07_sign21 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 21.csv")
user07_sign22 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 22.csv")
user07_sign23 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 23.csv")
user07_sign24 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 24.csv")
user07_sign25 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 25.csv")
user07_sign26 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 26.csv")
user07_sign27 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 27.csv")
user07_sign28 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 28.csv")
user07_sign29 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 29.csv")

user07_sign30 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 30.csv")
user07_sign31 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 31.csv")
user07_sign32 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 32.csv")
user07_sign33 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 33.csv")
user07_sign34 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 34.csv")
user07_sign35 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 35.csv")
user07_sign36 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 07 - Male, 14/Output Images - Sign 36.csv")

user08_sign00 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 00.csv")
user08_sign01 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 01.csv")
user08_sign02 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 02.csv")
user08_sign03 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 03.csv")
user08_sign04 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 04.csv")
user08_sign05 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 05.csv")
user08_sign06 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 06.csv")
user08_sign07 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 07.csv")
user08_sign08 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 08.csv")
user08_sign09 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 09.csv")

user08_sign10 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 10.csv")
user08_sign11 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 11.csv")
user08_sign12 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 12.csv")
user08_sign13 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 13.csv")
user08_sign14 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 14.csv")
user08_sign15 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 15.csv")
user08_sign16 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 16.csv")
user08_sign17 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 17.csv")
user08_sign18 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 18.csv")
user08_sign19 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 19.csv")

user08_sign20 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 20.csv")
user08_sign21 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 21.csv")
user08_sign22 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 22.csv")
user08_sign23 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 23.csv")
user08_sign24 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 24.csv")
user08_sign25 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 25.csv")
user08_sign26 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 26.csv")
user08_sign27 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 27.csv")
user08_sign28 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 28.csv")
user08_sign29 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 29.csv")

user08_sign30 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 30.csv")
user08_sign31 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 31.csv")
user08_sign32 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 32.csv")
user08_sign33 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 33.csv")
user08_sign34 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 34.csv")
user08_sign35 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 35.csv")
user08_sign36 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 08 - Male, 24/Output Images - Sign 36.csv")

user09_sign00 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 00.csv")
user09_sign01 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 01.csv")
user09_sign02 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 02.csv")
user09_sign03 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 03.csv")
user09_sign04 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 04.csv")
user09_sign05 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 05.csv")
user09_sign06 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 06.csv")
user09_sign07 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 07.csv")
user09_sign08 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 08.csv")
user09_sign09 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 09.csv")

user09_sign10 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 10.csv")
user09_sign11 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 11.csv")
user09_sign12 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 12.csv")
user09_sign13 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 13.csv")
user09_sign14 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 14.csv")
user09_sign15 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 15.csv")
user09_sign16 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 16.csv")
user09_sign17 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 17.csv")
user09_sign18 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 18.csv")
user09_sign19 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 19.csv")

user09_sign20 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 20.csv")
user09_sign21 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 21.csv")
user09_sign22 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 22.csv")
user09_sign23 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 23.csv")
user09_sign24 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 24.csv")
user09_sign25 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 25.csv")
user09_sign26 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 26.csv")
user09_sign27 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 27.csv")
user09_sign28 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 28.csv")
user09_sign29 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 29.csv")

user09_sign30 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 30.csv")
user09_sign31 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 31.csv")
user09_sign32 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 32.csv")
user09_sign33 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 33.csv")
user09_sign34 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 34.csv")
user09_sign35 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 35.csv")
user09_sign36 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 09 - Male, 26/Output Images - Sign 36.csv")

user10_sign00 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 00.csv")
user10_sign01 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 01.csv")
user10_sign02 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 02.csv")
user10_sign03 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 03.csv")
user10_sign04 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 04.csv")
user10_sign05 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 05.csv")
user10_sign06 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 06.csv")
user10_sign07 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 07.csv")
user10_sign08 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 08.csv")
user10_sign09 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 09.csv")

user10_sign10 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 10.csv")
user10_sign11 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 11.csv")
user10_sign12 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 12.csv")
user10_sign13 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 13.csv")
user10_sign14 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 14.csv")
user10_sign15 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 15.csv")
user10_sign16 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 16.csv")
user10_sign17 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 17.csv")
user10_sign18 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 18.csv")
user10_sign19 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 19.csv")

user10_sign20 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 20.csv")
user10_sign21 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 21.csv")
user10_sign22 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 22.csv")
user10_sign23 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 23.csv")
user10_sign24 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 24.csv")
user10_sign25 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 25.csv")
user10_sign26 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 26.csv")
user10_sign27 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 27.csv")
user10_sign28 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 28.csv")
user10_sign29 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 29.csv")

user10_sign30 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 30.csv")
user10_sign31 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 31.csv")
user10_sign32 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 32.csv")
user10_sign33 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 33.csv")
user10_sign34 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 34.csv")
user10_sign35 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 35.csv")
user10_sign36 = pd.read_csv("/kaggle/input/bangla-sign-alphabet-dataset/CSV Files/Subject 10 - Female, 21/Output Images - sign 36.csv")

# %% [markdown]
# ### ***Data Concatanetion***

# %%
df = pd.concat([user01_sign00, user01_sign01, user01_sign02, user01_sign03, user01_sign04, user01_sign05, user01_sign06, user01_sign07, user01_sign08, user01_sign09,
                user01_sign10, user01_sign11, user01_sign12, user01_sign13, user01_sign14, user01_sign15, user01_sign16, user01_sign17, user01_sign18, user01_sign19,
                user01_sign20, user01_sign21, user01_sign22, user01_sign23, user01_sign24, user01_sign25, user01_sign26, user01_sign27, user01_sign28, user01_sign29,
                user01_sign30, user01_sign31, user01_sign32, user01_sign33, user01_sign34, user01_sign35, user01_sign36,

                user02_sign00, user02_sign01, user02_sign02, user02_sign03, user02_sign04, user02_sign05, user02_sign06, user02_sign07, user02_sign08, user02_sign09,
                user02_sign10, user02_sign11, user02_sign12, user02_sign13, user02_sign14, user02_sign15, user02_sign16, user02_sign17, user02_sign18, user02_sign19,
                user02_sign20, user02_sign21, user02_sign22, user02_sign23, user02_sign24, user02_sign25, user02_sign26, user02_sign27, user02_sign28, user02_sign29,
                user02_sign30, user02_sign31, user02_sign32, user02_sign33, user02_sign34, user02_sign35, user02_sign36,

                user03_sign00, user03_sign01, user03_sign02, user03_sign03, user03_sign04, user03_sign05, user03_sign06, user03_sign07, user03_sign08, user03_sign09,
                user03_sign10, user03_sign11, user03_sign12, user03_sign13, user03_sign14, user03_sign15, user03_sign16, user03_sign17, user03_sign18, user03_sign19,
                user03_sign20, user03_sign21, user03_sign22, user03_sign23, user03_sign24, user03_sign25, user03_sign26, user03_sign27, user03_sign28, user03_sign29,
                user03_sign30, user03_sign31, user03_sign32, user03_sign33, user03_sign34, user03_sign35, user03_sign36,

                user04_sign00, user04_sign01, user04_sign02, user04_sign03, user04_sign04, user04_sign05, user04_sign06, user04_sign07, user04_sign08, user04_sign09,
                user04_sign10, user04_sign11, user04_sign12, user04_sign13, user04_sign14, user04_sign15, user04_sign16, user04_sign17, user04_sign18, user04_sign19,
                user04_sign20, user04_sign21, user04_sign22, user04_sign23, user04_sign24, user04_sign25, user04_sign26, user04_sign27, user04_sign28, user04_sign29,
                user04_sign30, user04_sign31, user04_sign32, user04_sign33, user04_sign34, user04_sign35, user04_sign36,
                
                user05_sign00, user05_sign01, user05_sign02, user05_sign03, user05_sign04, user05_sign05, user05_sign06, user05_sign07, user05_sign08, user05_sign09,
                user05_sign10, user05_sign11, user05_sign12, user05_sign13, user05_sign14, user05_sign15, user05_sign16, user05_sign17, user05_sign18, user05_sign19,
                user05_sign20, user05_sign21, user05_sign22, user05_sign23, user05_sign24, user05_sign25, user05_sign26, user05_sign27, user05_sign28, user05_sign29,
                user05_sign30, user05_sign31, user05_sign32, user05_sign33, user05_sign34, user05_sign35, user05_sign36,

                user06_sign00, user06_sign01, user06_sign02, user06_sign03, user06_sign04, user06_sign05, user06_sign06, user06_sign07, user06_sign08, user06_sign09,
                user06_sign10, user06_sign11, user06_sign12, user06_sign13, user06_sign14, user06_sign15, user06_sign16, user06_sign17, user06_sign18, user06_sign19,
                user06_sign20, user06_sign21, user06_sign22, user06_sign23, user06_sign24, user06_sign25, user06_sign26, user06_sign27, user06_sign28, user06_sign29,
                user06_sign30, user06_sign31, user06_sign32, user06_sign33, user06_sign34, user06_sign35, user06_sign36,

                user07_sign00, user07_sign01, user07_sign02, user07_sign03, user07_sign04, user07_sign05, user07_sign06, user07_sign07, user07_sign08, user07_sign09,
                user07_sign10, user07_sign11, user07_sign12, user07_sign13, user07_sign14, user07_sign15, user07_sign16, user07_sign17, user07_sign18, user07_sign19,
                user07_sign20, user07_sign21, user07_sign22, user07_sign23, user07_sign24, user07_sign25, user07_sign26, user07_sign27, user07_sign28, user07_sign29,
                user07_sign30, user07_sign31, user07_sign32, user07_sign33, user07_sign34, user07_sign35, user07_sign36, 

                user08_sign00, user08_sign01, user08_sign02, user08_sign03, user08_sign04, user08_sign05, user08_sign06, user08_sign07, user08_sign08, user08_sign09,
                user08_sign10, user08_sign11, user08_sign12, user08_sign13, user08_sign14, user08_sign15, user08_sign16, user08_sign17, user08_sign18, user08_sign19,
                user08_sign20, user08_sign21, user08_sign22, user08_sign23, user08_sign24, user08_sign25, user08_sign26, user08_sign27, user08_sign28, user08_sign29,
                user08_sign30, user08_sign31, user08_sign32, user08_sign33, user08_sign34, user08_sign35, user08_sign36,

                user09_sign00, user09_sign01, user09_sign02, user09_sign03, user09_sign04, user09_sign05, user09_sign06, user09_sign07, user09_sign08, user09_sign09,
                user09_sign10, user09_sign11, user09_sign12, user09_sign13, user09_sign14, user09_sign15, user09_sign16, user09_sign17, user09_sign18, user09_sign19,
                user09_sign20, user09_sign21, user09_sign22, user09_sign23, user09_sign24, user09_sign25, user09_sign26, user09_sign27, user09_sign28, user09_sign29,
                user09_sign30, user09_sign31, user09_sign32, user09_sign33, user09_sign34, user09_sign35, user09_sign36,
                
                user10_sign00, user10_sign01, user10_sign02, user10_sign03, user10_sign04, user10_sign05, user10_sign06, user10_sign07, user10_sign08, user10_sign09,
                user10_sign10, user10_sign11, user10_sign12, user10_sign13, user10_sign14, user10_sign15, user10_sign16, user10_sign17, user10_sign18, user10_sign19,
                user10_sign20, user10_sign21, user10_sign22, user10_sign23, user10_sign24, user10_sign25, user10_sign26, user10_sign27, user10_sign28, user10_sign29,
                user10_sign30, user10_sign31, user10_sign32, user10_sign33, user10_sign34, user10_sign35, user10_sign36,
                ])

# %%
features = df.iloc[:,1:-1]
labels = df.iloc[:,-1]

features_np = np.array(features)

from sklearn.preprocessing import StandardScaler

sc_X = StandardScaler()
x = sc_X.fit_transform(features_np)
y = labels

# %% [markdown]
# ### ***Train Test Split***

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=0)
cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %% [markdown]
# ### ***Classification : KNN***

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

np.random.seed(123)

import time
start_time_KNN = time.time()

modelKNN = KNeighborsClassifier(n_neighbors=3)
modelKNN.fit(x_train, y_train)

y_predKNN = modelKNN.predict(x_test)

accuracy_KNN = accuracy_score(y_test, y_predKNN)
precision_KNN = precision_score(y_test, y_predKNN, average='weighted')
recall_KNN = recall_score(y_test, y_predKNN, average='weighted')
f1_KNN = f1_score(y_test, y_predKNN, average='weighted')

end_time_KNN = time.time()
time_KNN = end_time_KNN - start_time_KNN

print('KNN - Accuracy  : %.2f' % (accuracy_KNN*100), '%')
print('KNN - F1-Score  : %.2f' % (f1_KNN*100), '%')
print('KNN - Recall    : %.2f' % (recall_KNN*100), '%')
print('KNN - Precision : %.2f' % (precision_KNN*100), '%')
print('KNN - Time Taken : %.2f' % time_KNN, 'seconds')
# Out:
# KNN - Accuracy  : 98.49 %
# KNN - F1-Score  : 98.49 %
# KNN - Recall    : 98.49 %
# KNN - Precision : 98.50 %
# KNN - Time Taken : 3.52 seconds

# %% [markdown]
# ### ***Classification : SVM***

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

np.random.seed(123)

import time
start_time_SVM = time.time()

modelSVM_RBF = SVC(kernel = 'rbf')
modelSVM_RBF.fit(x_train, y_train)

y_predSVM_RBF = modelSVM_RBF.predict(x_test)

accuracy_SVM = accuracy_score(y_test, y_predSVM_RBF)
precision_SVM = precision_score(y_test, y_predSVM_RBF, average='weighted')
recall_SVM = recall_score(y_test, y_predSVM_RBF, average='weighted')
f1_SVM = f1_score(y_test, y_predSVM_RBF, average='weighted')

end_time_SVM = time.time()
time_SVM = end_time_SVM - start_time_SVM

print('SVM - Accuracy  : %.2f' % (accuracy_SVM*100), '%')
print('SVM - F1-Score  : %.2f' % (f1_SVM*100), '%')
print('SVM - Recall    : %.2f' % (recall_SVM*100), '%')
print('SVM - Precision : %.2f' % (precision_SVM*100), '%')
print('KNN - Time Taken : %.2f' % time_SVM, 'seconds')
# Out:
# SVM - Accuracy  : 96.55 %
# SVM - F1-Score  : 96.55 %
# SVM - Recall    : 96.55 %
# SVM - Precision : 96.58 %
# KNN - Time Taken : 26.43 seconds

# %% [markdown]
# ### ***Classification : RFC***

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

np.random.seed(123)

import time
start_time_RFC = time.time()

modelRFC = RandomForestClassifier(n_estimators = 47, criterion = 'gini')
modelRFC.fit(x_train, y_train)

y_predRFC = modelRFC.predict(x_test)

accuracy_RFC = accuracy_score(y_test, y_predRFC)
precision_RFC = precision_score(y_test, y_predRFC, average='weighted')
recall_RFC = recall_score(y_test, y_predRFC, average='weighted')
f1_RFC = f1_score(y_test, y_predRFC, average='weighted')

end_time_RFC = time.time()
time_RFC = end_time_RFC - start_time_RFC

print('RFC - Accuracy  : %.2f' % (accuracy_RFC*100), '%')
print('RFC - F1-Score  : %.2f' % (precision_RFC*100), '%')
print('RFC - Recall    : %.2f' % (recall_RFC*100), '%')
print('RFC - Precision : %.2f' % (f1_RFC*100), '%')
print('RFC - Time Taken : %.2f' % time_RFC, 'seconds')
# Out:
# RFC - Accuracy  : 98.53 %
# RFC - F1-Score  : 98.54 %
# RFC - Recall    : 98.53 %
# RFC - Precision : 98.53 %
# RFC - Time Taken : 12.11 seconds

# %% [markdown]
# #### Accuracy Table

# %%
from tabulate import tabulate

head = ["Classifier", "Accuracy", "Precision", "Recall", "Accuracy"]

mydata = [
    ["KNN", accuracy_KNN*100, precision_KNN*100, recall_KNN*100, f1_KNN*100],
    ["SVM", accuracy_SVM*100, precision_SVM*100, recall_SVM*100, f1_SVM*100],
    ["RFC", accuracy_RFC*100, precision_RFC*100, recall_RFC*100, f1_RFC*100],
]

print(tabulate(mydata, headers=head, tablefmt="plain"))
# Out:
# Classifier      Accuracy    Precision    Recall    Accuracy
# KNN              98.4865      98.4957   98.4865     98.4865
# SVM              96.5541      96.5812   96.5541     96.5478
# RFC              98.527       98.5366   98.527      98.5266

# %% [markdown]
# ### ***Classification : ANN***

# %%
import keras
from keras.callbacks import CSVLogger
from keras.models import Sequential
from keras.layers import Dense, Dropout, LeakyReLU
import time
import tensorflow as tf


np.random.seed(45)
tf.random.set_seed(45)

csv_logger = CSVLogger('log.csv', append=True, separator=';')

classifier = Sequential()
classifier.add(Dense(64, input_shape = x_train[0].shape))

classifier.add(Dense(128))
classifier.add(LeakyReLU(alpha=0.1))

classifier.add(Dense(128))
classifier.add(LeakyReLU(alpha=0.1))
classifier.add(Dropout(rate=0.3))

classifier.add(Dense(74))
classifier.add(LeakyReLU(alpha=0.1))
classifier.add(Dropout(rate=0.25))

classifier.add(Dense(37, activation='softmax'))

start_time = time.time()
classifier.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'] )
classifier.fit(x_train, y_train, validation_split= 0.15, epochs=100, batch_size=37, callbacks=[csv_logger])
end_time = time.time()
# Out:
# Epoch 1/100
# 680/680 [==============================] - 2s 3ms/step - loss: 1.5250 - accuracy: 0.5209 - val_loss: 0.6125 - val_accuracy: 0.7921
# Epoch 2/100
# 680/680 [==============================] - 2s 3ms/step - loss: 0.6560 - accuracy: 0.7676 - val_loss: 0.3610 - val_accuracy: 0.8811
# Epoch 3/100
# 680/680 [==============================] - 2s 3ms/step - loss: 0.4754 - accuracy: 0.8298 - val_loss: 0.2660 - val_accuracy: 0.9079
# Epoch 4/100
# 680/680 [==============================] - 2s 2ms/step - loss: 0.3773 - accuracy: 0.8628 - val_loss: 0.2367 - val_accuracy: 0.9198
# Epoch 5/100
# 680/680 [==============================] - 2s 2ms/step - loss: 0.3206 - accuracy: 0.8822 - val_loss: 0.1979 - val_accuracy: 0.9338
# Epoch 6/100
# 680/680 [==============================] - 2s 2ms/step - loss: 0.2816 - accuracy: 0.8979 - val_loss: 0.1660 - val_accuracy: 0.9426
# Epoch 7/100
# ...

# %%
time_taken = end_time - start_time
print("Time : %.3f" % time_taken, 'seconds')
# Out:
# Time : 202.348 seconds

# %%
print("Evaluation on test data : ")
results = classifier.evaluate(x_test, y_test, batch_size=10)
accuracyANN = results[1]*100
print("Test Accuracy : %.2f" % accuracyANN,'%')
# Out:
# Evaluation on test data :
# 740/740 [==============================] - 2s 2ms/step - loss: 0.0356 - accuracy: 0.9941
# Test Accuracy : 99.41 %

# %% [markdown]
# ### ***Confusion Matrix***

# %%
import numpy as np
import sklearn
from sklearn.metrics import confusion_matrix

test_pred = classifier.predict(x_test)
y_pred = np.argmax(test_pred, axis=1)

confusion_matrix = sklearn.metrics.confusion_matrix(y_test, y_pred)
# Out:
# 232/232 [==============================] - 0s 1ms/step

# %%
print(confusion_matrix)
# Out:
# [[192   0   0 ...   0   0   0]
#  [  0 203   0 ...   0   0   0]
#  [  0   0 200 ...   0   0   0]
#  ...
#  [  0   1   0 ... 218   0   0]
#  [  0   0   0 ...   0 203   0]
#  [  0   0   0 ...   0   0 178]]

# %%
import seaborn as sns

ax = sns.heatmap(confusion_matrix, annot=True, cmap='Blues')

plt.savefig("Confusion Matrix.png", dpi=1000, format='png')
plt.show()

# %% [markdown]
# ### ***Individual Accuracy, Precision, Recall, F1 Score***

# %%
new_arr = confusion_matrix

# %%
total = 0
for i in range(0, len(new_arr[0])) : 
    for j in range(0, len(new_arr[0])) : 
        total += new_arr[i][j]

# %%
tp, fp, fn, tn = [], [], [], []
precision, recall, f1_score, accuracy = [], [], [], []

for i in range(0,len(new_arr[0])) : 
    tp.append(new_arr[i][i])
    temp_fp = 0
    temp_fn = 0
    for k in range(0,len(new_arr[0])) :
        temp_fp += new_arr[i][k]
        temp_fn += new_arr[k][i]
    fp.append(temp_fp - new_arr[i][i])
    fn.append(temp_fn - new_arr[i][i])

for i in range(0,len(new_arr[0])) : 
    tn.append(total-(tp[i]+fp[i]+fn[i]))

for i in range(0,len(new_arr[0])) :  
    precision.append(tp[i]/(tp[i]+fp[i]))
    recall.append(tp[i]/(tp[i]+fn[i]))
    f1_score.append((2*precision[i]*recall[i])/(precision[i]+recall[i]))
    accuracy.append((tp[i]+tn[i])/total)

# %% [markdown]
# ### ***Saving the outputs in separate log files***

# %%
with open('log_precision.csv', 'w') as f:
    np.savetxt(f, precision, delimiter=';')
with open('log_recall.csv', 'w') as f:
    np.savetxt(f, recall, delimiter=';')
with open('log_f1_score.csv', 'w') as f:
    np.savetxt(f, f1_score, delimiter=';')
with open('log_accuracy.csv', 'w') as f:
    np.savetxt(f, accuracy, delimiter=';')
with open('log_accuracy.csv', 'w') as f:
    np.savetxt(f, accuracy, delimiter=';')
    
with open('tp.csv', 'w') as f:
    np.savetxt(f, tp, delimiter=';')
with open('tn.csv', 'w') as f:
    np.savetxt(f, tn, delimiter=';')
with open('fp.csv', 'w') as f:
    np.savetxt(f, fp, delimiter=';')
with open('fn.csv', 'w') as f:
    np.savetxt(f, fn, delimiter=';')

# %%
from tabulate import tabulate
head = ["Sign", "TP", "FP", "FN", "TN", "Precision", "Recall", "F1-Score", "Accuracy"]
# assign data
mydata = []
row = []
for i in range(0, len(tp)) : 
    row = i, tp[i], fp[i], fn[i], tn[i], precision[i], recall[i], f1_score[i], accuracy[i]
    mydata.append(row)

# display table
print(tabulate(mydata, headers=head, tablefmt="simple"))
# Out:
#   Sign    TP    FP    FN    TN    Precision    Recall    F1-Score    Accuracy
# ------  ----  ----  ----  ----  -----------  --------  ----------  ----------
#      0   192     0     3  7205     1         0.984615    0.992248    0.999595
#      1   203     0     1  7196     1         0.995098    0.997543    0.999865
#      2   200     2     0  7198     0.990099  1           0.995025    0.99973
#      3   198     2     3  7197     0.99      0.985075    0.987531    0.999324
#      4   193     0     1  7206     1         0.994845    0.997416    0.999865
#      5   197     0     0  7203     1         1           1           1
#      6   178     0     1  7221     1         0.994413    0.997199    0.999865
#      7   196     3     4  7197     0.984925  0.98        0.982456    0.999054
#      8   194     0     1  7205     1         0.994872    0.997429    0.999865
#      9   199     7     3  7191     0.966019  0.985149    0.97549     0.998649
# ...

# %% [markdown]
# ### Cumulative Scores

# %%
total_tp, total_tn, total_fp, total_fn, total_accuracy, total_precision, total_recall, total_f1_score = 0, 0, 0, 0, 0, 0, 0, 0

for i in range(0, len(tp)) : 
    total_tp += tp[i]
    total_tn += tn[i]
    total_fp += fp[i]
    total_fn += fn[i]
    total_accuracy += accuracy[i]
    total_precision += precision[i]
    total_recall += recall[i]
    total_f1_score += f1_score[i]

# %% [markdown]
# #### Micro

# %%
micro_accuracy = (total_tp+total_tn)/(total_tp+total_tn+total_fp+total_fn)
micro_precision = total_tp/(total_tp+total_fp)
micro_recall = total_tp/(total_tp+total_fn)
micro_f1_score = (2*micro_precision*micro_recall)/(micro_precision+micro_recall)

print("Micro-Accuracy  : %.2f" % (micro_accuracy*100),'%')
print("Micro-Precision : %.2f" % (micro_precision*100),'%')
print("Micro-Recall    : %.2f" % (micro_recall*100),'%')
print("Micro-F1-Score  : %.2f" % (micro_f1_score*100),'%')
# Out:
# Micro-Accuracy  : 99.97 %
# Micro-Precision : 99.41 %
# Micro-Recall    : 99.41 %
# Micro-F1-Score  : 99.41 %

# %% [markdown]
# #### Macro

# %%
macro_accuracy = total_accuracy/37
macro_precision = total_precision/37
macro_recall = total_recall/37
macro_f1_score = total_f1_score/37

print("Macro-Accuracy  : %.2f" % (macro_accuracy*100),'%')
print("Macro-Precision : %.2f" % (macro_precision*100),'%')
print("Macro-Recall    : %.2f" % (macro_recall*100),'%')
print("Macro-F1-Score  : %.2f" % (macro_f1_score*100),'%')
# Out:
# Macro-Accuracy  : 99.97 %
# Macro-Precision : 99.41 %
# Macro-Recall    : 99.41 %
# Macro-F1-Score  : 99.41 %

# %% [markdown]
# ### ***Graph***

# %%
import seaborn as sns
import matplotlib.pyplot as plt

signs = []
for i in range(0, len(tp)) : 
    signs.append(i)

# Create figure and subplots
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

# Plot 1 : Signs vs. Accuracy
sns.scatterplot(x=signs, y=accuracy, ax=axs[0,0])
axs[0,0].set_xlabel("Signs")
axs[0,0].set_ylabel("Accuracy")
axs[0,0].set_ylim(.90,1)
axs[0,0].set_title("Plot 1 : Signs vs. Accuracy")

# Plot 2 : Signs vs. Precision
sns.scatterplot(x=signs, y=precision, ax=axs[0,1])
axs[0,1].set_xlabel("Signs")
axs[0,1].set_ylabel("Precision")
axs[0,1].set_ylim(.90,1)
axs[0,1].set_title("Plot 2 : Signs vs. Precision")

# Plot 3 : Signs vs. Recall
sns.scatterplot(x=signs, y=recall, ax=axs[1,0])
axs[1,0].set_xlabel("Signs")
axs[1,0].set_ylabel("Recall")
axs[1,0].set_ylim(.90,1)
axs[1,0].set_title("Plot 3 : Signs vs. Recall")

# Plot 4 : Signs vs. F1-Scores
sns.scatterplot(x=signs, y=precision, ax=axs[1,1])
axs[1,1].set_xlabel("Signs")
axs[1,1].set_ylabel("F1-Score")
axs[1,1].set_ylim(.90,1)
axs[1,1].set_title("Plot 4 : Signs vs. F1-Score")

# Adjust spacing between subplots
plt.tight_layout()
plt.savefig("Individual Scores.png", dpi=1000, format='png')
